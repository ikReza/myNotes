# %% [markdown]
# <h2 style="text-align: center">Naive Bayes</h2>
#
# It based on Bayes theorem and the approach is naive compared to other algorithms.
#
# [youtube tutorial 1](https://www.youtube.com/watch?v=Q8l0Vip5YUw)
#
# ![naive bayes](bayes.JPG)
#
# ![chain_rule](chain_rule.JPG)

# %% [markdown]
# > What is conditional probability?
#
# *If an email contains the word "buy", what is the probability that it is spam?* This is an example of conditional probability

# %%
(.1*.05)*100
# Out:
# 0.5000000000000001

# %%
from sklearn.datasets import fetch_20newsgroups

# %%
data = fetch_20newsgroups()

# %%
data.keys()
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR'])

# %%
print(data.DESCR)
# Out:
# .. _20newsgroups_dataset:
#
# The 20 newsgroups text dataset
# ------------------------------
#
# The 20 newsgroups dataset comprises around 18000 newsgroups posts on
# 20 topics split in two subsets: one for training (or development)
# and the other one for testing (or for performance evaluation). The split
# between the train and test set is based upon a messages posted before
# and after a specific date.
#
# This module contains two loaders. The first one,
# :func:`sklearn.datasets.fetch_20newsgroups`,
# returns a list of the raw texts that can be fed to text feature
# extractors such as :class:`sklearn.feature_extraction.text.CountVectorizer`
# with custom parameters so as to extract feature vectors.
# The second one, :func:`sklearn.datasets.fetch_20newsgroups_vectorized`,
# returns ready-to-use features, i.e., it is not necessary to use a feature
# extractor.
#
# **Data Set Characteristics:**
#
#     =================   ==========
#     Classes                     20
# ...

# %%
categories = data.target_names

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train = fetch_20newsgroups(subset="train", categories=categories)
test = fetch_20newsgroups(subset="test", categories=categories)

# %%
print(len(train.data), len(test.data))
round((len(test.data)/(len(test.data)+len(train.data)))*100)
# Out:
# 11314 7532
# 40

# %%
X_train, X_test, y_train, y_test = (train.data, test.data, train.target, test.target)

# %% [markdown]
# #### import necessary packages

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %% [markdown]
# #### create model

# %%
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

#fit the model
model.fit(X_train, y_train)

#prediction
y_pred = model.predict(X_test)

# %%
y_pred = model.predict(["sing a song"])
y_pred
# Out:
# array([14], dtype=int64)

# %% [markdown]
# #### confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from matplotlib import style
style.use("default")

# %%
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm.T, square=True, annot=True, fmt="d", cbar=False, 
            xticklabels=train.target_names, yticklabels=train.target_names)

#plotting
plt.xlabel("True label")
plt.ylabel("Predicted label")
plt.autoscale()
plt.show()

# %% [markdown]
# #### Predicting category based on our training

# %%
def predict_category(s, train=train, model=model):
    pred = model.predict([s])
    return train.target_names[pred[0]]

# %%
predict_category("play football")
# Out:
# 'rec.sport.hockey'

# %% [markdown]
# ## Another example

# %%
import pandas as pd
df = pd.read_csv("spam.csv")
df.head(10)
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
# 5        2949   ham  Subject: ehronline web address change\r\nthis ...
# 6        2793   ham  Subject: spring savings certificate - take 30 ...
# 7        4185  spam  Subject: looking for medication ? we ` re the ...
# 8        2641   ham  Subject: noms / actual flow for 2 / 26\r\nwe a...
# 9        1870   ham  Subject: nominations for oct . 21 - 23 , 2000\...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0

# %%
df.shape
# Out:
# (5171, 4)

# %%
trial = df.copy()
print(trial.columns)
trial.drop(["Unnamed: 0", "label_num"],axis = 1, inplace = True)
trial.groupby("label").describe()
# Out:
# Index(['Unnamed: 0', 'label', 'text', 'label_num'], dtype='object')
#        text
#       count unique                                                top freq
# label
# ham    3672   3531  Subject: calpine daily gas nomination\r\n>\r\n...   20
# spam   1499   1462                                      Subject: \r\n   16

# %%
# check missing data (NAN, NaN, na)
trial.isnull().sum()
# Out:
# label    0
# text     0
# dtype: int64

# %%
X = df.text
y = df.label_num

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.8785769528228925

# %%
emails = ["Hello, nice to meet you. How you doing these days",
         "Upto 20% discount on parking, exclusive offer just for you. Don't miss this reward",
         "We're going to Saint Martin today. Let's go"]

# %%
y_pred = model.predict(emails)
y_pred
# Out:
# array([0, 0, 0], dtype=int64)

# %%
emails = ["Give us money. This not spam"]
y_pred = model.predict(emails)
y_pred
# Out:
# array([1], dtype=int64)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
msg = str(y_pred[0])

# %%
type(msg)
# Out:
# str
